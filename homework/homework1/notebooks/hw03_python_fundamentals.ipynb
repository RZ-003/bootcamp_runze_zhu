# %% [markdown]
# # Python Fundamentals

# %% [markdown]
# ## 0) Setup

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## 1) NumPy Operations
# Create an array and perform elementwise ops. Then compare a Python loop vs a NumPy vectorized approach for speed.

# %%
x = np.array([1, 2, 3, 4, 5])
print("x:", x)
y = x ** 2
print("y = x**2:", y)

# %% [markdown]
# ## 2) Load Dataset & Inspect
# Load `data/starter_data.csv`. Then run `.info()` and `.head()`.

# %%
if not DATA_CSV.exists():
    raise FileNotFoundError("Missing data/starter_data.csv.")

df = pd.read_csv(DATA_CSV)
display(df.info())
df.head()

# %% [markdown]
# ## 3) Summary Statistics
# Use `.describe()` for numeric columns.

# %%
desc = df.describe(include=[np.number]).T

# %% [markdown]
# ## 4) Save Outputs
# Save summary stats to `data/processed/summary.csv` (and `.json` as a bonus).

# %% [markdown]
# ## 5) Reusable Function
# We'll import `get_summary_stats` from `src/utils.py` (already created for you) and use it here.
